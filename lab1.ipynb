# %%
>>> import pandas as pd
>>> df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
print(df[df.Sex=='male'][df.Pclass==1])
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# 30            31         0       1
# 34            35         0       1
# 35            36         0       1
# 54            55         0       1
# 55            56         1       1
# 62            63         0       1
# 64            65         0       1
# 83            84         0       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 124          125         0       1
# 137          138         0       1
# 139          140         0       1
# 155          156         0       1
# 168          169         0       1
# 170          171         0       1
# 174          175         0       1
# 185          186         0       1
# ...

# %%
print(df.PassengerId[df.Age<18][df.Pclass==2].count())
# Out:
# 23

# %%
print(df.PassengerId[df.SibSp==0][df.Parch==0].count())
# Out:
# 537

# %%
print(df.PassengerId[df.Embarked=='Q'][df.Fare > df.Fare.median()].count())
# Out:
# 20

# %%
print(df.Age[df.Sex=='female'].median())
# Out:
# 27.0

# %%
print(df.PassengerId[ df.Age > 60][df.SibSp==0][df.Parch==0].count())
# Out:
# 18

# %%
import matplotlib.pyplot as plt
stchild = df[df.Age < 18]
stchild.pivot_table('Age', 'Pclass', 'Survived','count').plot(kind='bar', stacked=True)

# %%
print(df.groupby('Embarked').Fare.median())
# Out:
# Embarked
# C    29.70
# Q     7.75
# S    13.00
# Name: Fare, dtype: float64

# %%
print(df.groupby('Pclass').Fare.median())
# Out:
# Pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: Fare, dtype: float64
